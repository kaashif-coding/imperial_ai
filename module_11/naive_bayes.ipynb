# %%
import nltk
from nltk.corpus import movie_reviews

# %%
movie_reviews
# Out:
# <CategorizedPlaintextCorpusReader in '.../corpora/movie_reviews' (not loaded yet)>

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = list(all_words)[:2000]  # top 2000 words as features
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/corpus/util.py:85, in LazyCorpusLoader.__load(self)
#      84 try:
# ---> 85     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86 except LookupError:
#
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/data.py:877, in find(resource_name, paths)
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'movie_reviews' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('movie_reviews')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/movie_reviews.zip/movie_reviews/'
#
#   Searched in:
#     - '/Users/kaashif/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/share/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
#       2 word_features = list(all_words)[:2000]  # top 2000 words as features
#
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/corpus/util.py:129, in LazyCorpusLoader.__getattr__(self, attr)
#     124 if attr.startswith("__") and attr.endswith("__"):
#     125     raise AttributeError(
#     126         f"{type(self).__name__} object has no attribute {attr!r}"
#     127     )
# --> 129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
#     132 return getattr(self, attr)
#
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/corpus/util.py:87, in LazyCorpusLoader.__load(self)
#      85             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86         except LookupError:
# ---> 87             raise e
#      89 # Load the corpus.
#      90 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/corpus/util.py:82, in LazyCorpusLoader.__load(self)
#      80 else:
#      81     try:
# ---> 82         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      83     except LookupError as e:
#      84         try:
#
# File ~/Development/PyCharmProjects/Imperial_course/.venv/lib/python3.12/site-packages/nltk/data.py:877, in find(resource_name, paths)
#     875 sep = "*" * 70
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'movie_reviews' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('movie_reviews')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/movie_reviews'
#
#   Searched in:
#     - '/Users/kaashif/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/share/nltk_data'
#     - '/Users/kaashif/Development/PyCharmProjects/Imperial_course/.venv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
